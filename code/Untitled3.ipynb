# %%
import lightkurve as lk
lc = lk.search_lightcurvefile('l98-59').download()
lc = lc.PDCSAP_FLUX.normalize().remove_nans().flatten()
lc.interact_bls(notebook_url='localhost:8888', maximum_period=20)
# Out:
# <script src="http://localhost:36357/autoload.js?bokeh-autoload-element=3467&bokeh-absolute-url=http://localhost:36357&resources=none" id="3467"></script>
